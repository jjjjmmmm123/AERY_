# %%
import pandas as pd
import numpy as np
import pickle

# %%
dataset = pd.read_csv("input.csv")

# %%
dataset
# Out:
#      Realistic  Investigate  Artistic    Social  Enterprising  Conventional  \
# 0     0.428571     0.285714  0.428571  0.142857      0.571429      0.571429
# 1     0.714286     1.000000  0.857143  0.428571      0.285714      0.857143
# 2     0.571429     0.428571  0.285714  0.571429      0.285714      0.571429
# 3     0.571429     0.000000  0.142857  0.857143      0.571429      0.857143
# 4     0.571429     0.571429  0.142857  0.285714      0.142857      0.571429
# ..         ...          ...       ...       ...           ...           ...
# 495   0.571429     0.428571  0.428571  0.571429      0.571429      0.428571
# 496   0.571429     0.428571  0.428571  0.571429      0.428571      0.714286
# 497   0.571429     0.428571  0.428571  0.571429      0.714286      0.428571
# 498   0.571429     0.428571  0.428571  0.571429      0.428571      0.714286
# 499   0.571429     0.428571  0.428571  0.571429      0.428571      0.714286
#
#      Linguistic  Logical-mathematical  Spatial  Bodily-Kinesthetic  Musical  \
# 0             4                     5        5                   5        6
# 1             1                     1        2                   1        1
# 2             4                     4        4                   3        2
# 3             2                     3        4                   5        3
# 4             2                     6        5                   1        5
# ..          ...                   ...      ...                 ...      ...
# 495           7                     3        4                   5        3
# 496           4                     5        3                   3        2
# 497           4                     5        3                   3        2
# 498           7                     5        3                   5        3
# 499           2                     6        3                   5        8
#
#      Interpersonal  Intrapersonal  Naturalistic  MATH  ENG  SCI  SOC-SCI  \
# 0                3              5             6    86   81   84       87
# 1                2              1             3    90   90   88       87
# 2                1              5             4    92   91   89       89
# 3                5              6             3    90   92   91       90
# 4                3              2             3    92   90   89       88
# ..             ...            ...           ...   ...  ...  ...      ...
# 495              5              4             3    85   90   86       88
# 496              3              4             2    85   90   86       88
# 497              3              4             2    94   97   91       95
# 498              4              2             3    84   93   91       96
# 499              2              4             4    88   93   92       86
#
#      CLASS
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# ..     ...
# 495    4.0
# 496    4.0
# 497    4.0
# 498    4.0
# 499    4.0
#
# [500 rows x 19 columns]

# %%
riasec = ["Realistic", "Investigate", "Artistic", "Social", "Enterprising", "Conventional"]
learning_style = ["Linguistic", "Logical-mathematical", "Spatial", "Bodily-Kinesthetic", "Musical", "Interpersonal", "Intrapersonal", "Naturalistic",]

# %%
dataset[riasec] = dataset[riasec]/7

# %%
X = dataset.iloc[:, 0:18].values
y = dataset.iloc[:, 18].values

# %%
z = dataset.iloc[:, 0:5].values
z =
# Out:
# (500, 5)

# %%
X.shape
# Out:
# (500, 18)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

X_train
# Out:
# array([[-1.040833  , -1.01149463,  1.52752523, ..., -0.62897498,
#         -0.04818094, -0.14078673],
#        [ 0.96076892, -1.01149463, -0.65465367, ..., -0.05717954,
#         -0.44035141, -0.80666989],
#        [ 0.96076892,  0.98863599, -0.65465367, ...,  0.80051361,
#          0.34398952, -1.13961148],
#        ...,
#        [-1.040833  ,  0.98863599, -0.65465367, ..., -0.05717954,
#         -0.83252187, -0.80666989],
#        [ 0.96076892, -1.01149463, -0.65465367, ..., -0.05717954,
#          0.34398952,  0.19215486],
#        [ 0.96076892, -1.01149463, -0.65465367, ...,  1.65820677,
#          1.12833045,  1.85686277]])

# %%
from sklearn.ensemble import RandomForestClassifier

regressor = RandomForestClassifier(n_estimators=100, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[37  0  1  2]
#  [ 0 40  1  0]
#  [ 0  1 36  0]
#  [ 0  3  0 29]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.93      0.96        40
#            2       0.91      0.98      0.94        41
#            3       0.95      0.97      0.96        37
#            4       0.94      0.91      0.92        32
#
#     accuracy                           0.95       150
#    macro avg       0.95      0.94      0.95       150
# weighted avg       0.95      0.95      0.95       150
#
# 0.9466666666666667

# %%
filename = 'random_forest_model.sav'
pickle.dump(regressor, open(filename, 'wb'))

# %%
pickle.dump(sc, open('scaler.pkl','wb'))
